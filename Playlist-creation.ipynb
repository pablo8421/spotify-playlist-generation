# %%
#imports
import time
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth
import pandas as pd

# %%
#Spotify connection
client_id = 'CLIENT-ID-HERE'
client_secret = 'CLIENT-SECRET-HERE'

username = 'pablo8421'

scope='user-library-read playlist-modify-public'
redirect_uri='http://localhost:7777/callback'

# %%
#Spotify api connection

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=client_id,
                                               client_secret=client_secret,
                                               redirect_uri=redirect_uri,
                                               scope=scope))

# %%
# Load pdf with cluster 
songs = pd.read_csv('D:/Pablo/clases/UJM/2. Semester, 2021/Data Mining/Project/tracks_clusterized_metropopolis.csv')

songs.head()
# Out:
#    Unnamed: 0                      id                     name       artist  \
# 0           1  7odLILAvE27EORYkRWfw5U  Caution - Wasatch Style  The Killers
# 1           2  0SieiDcGvj8cZ0K4hcT3Zd              Dying Breed  The Killers
# 2           3  150z2vDAwttNyNxEJFve50             Life To Come  The Killers
# 3           4  6Xyn0CrKfHeAo5eI8I1cDj            Run For Cover  The Killers
# 4           5  06OYfrtoQwYk2Ju70MiBgS         Miss Atomic Bomb  The Killers
#
#    duration_ms  explicit  popularity  danceability  energy  key  ...  mode  \
# 0       197853     False          55         0.661   0.612    6  ...     1
# 1       246000     False          58         0.656   0.780    1  ...     1
# 2       271933     False           0         0.470   0.869    0  ...     1
# 3       223066     False           0         0.461   0.957    5  ...     1
# 4       294760     False           0         0.558   0.726   10  ...     1
#
# ...

# %%
# Create playlist
playlist_name = 'Not so happy Metropopolis'

sp.user_playlist_create(username, name=playlist_name)
# Out:
# {'collaborative': False,
#  'description': '',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/4ZtYEo05zBEeriTG4MeExu'},
#  'followers': {'href': None, 'total': 0},
#  'href': 'https://api.spotify.com/v1/playlists/4ZtYEo05zBEeriTG4MeExu',
#  'id': '4ZtYEo05zBEeriTG4MeExu',
#  'images': [],
#  'name': 'Not so happy Metropopolis',
#  'owner': {'display_name': 'pablo8421',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/pablo8421'},
#   'href': 'https://api.spotify.com/v1/users/pablo8421',
#   'id': 'pablo8421',
#   'type': 'user',
#   'uri': 'spotify:user:pablo8421'},
#  'primary_color': None,
#  'public': True,
#  'snapshot_id': 'MSxiY2YyZjZkNTM0NDYzZGFjNzE0ZjhmNWQ1MTU5MGU5Njk1OTYxMTYw',
#  'tracks': {'href': 'https://api.spotify.com/v1/playlists/4ZtYEo05zBEeriTG4MeExu/tracks',
#   'items': [],
#   'limit': 100,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 0},
#  'type': 'playlist',
# ...

# %%
track_ids = songs[songs['cluster'] == 5]['id']

print(track_ids)
# Out:
# 11     5ZQ7VIzPivvIB1z4Eu8WFH
# 20     33Erxwd8RV55M6ZX6KigNt
# 22     5VpgaWuqcWho0uJMniRNDs
# 25     4c0WkzJbzDU750TXWarrk1
# 27     7lPN2DXiMsVn7XUKtOW1CS
#                 ...
# 909    3WKg25vrbjJlkhsgl2W4p3
# 920    3gVuz4Bhvxb2J0iGSH8bCZ
# 921    2VcAgFuGEly1AYUEvHzy0w
# 922    6oI3Inlpzlik5e7cy4Sdi8
# 981    4I3pKTGIAVjefIGumpCSdS
# Name: id, Length: 157, dtype: object

# %%
# Obtained from the response in the creation
playlist_id = 'PLAYLIST-ID-HERE'

# Iterate over a batch size of 50, a maximum of 100 songs can be added for each request
batch_length = 50
for i in range(0,(len(track_ids)+batch_length) // batch_length):
    sp.user_playlist_add_tracks(username, playlist_id, track_ids[batch_length*i:batch_length*i+batch_length])
